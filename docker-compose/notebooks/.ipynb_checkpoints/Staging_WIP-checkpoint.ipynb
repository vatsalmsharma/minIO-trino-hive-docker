# %%
import sys
sys.path.append("../../src")  # tell Python where to find modules

print(sys.path)
from app_config import AppConfig

config = AppConfig("../mne_configs/OCR_INPUT.json")
# Out:
# ['/opt/spark/python/lib/py4j-0.10.9.7-src.zip', '/tmp/spark-7878b93b-b54e-4574-bc58-cb7767a929cd/userFiles-ab7d9cd7-8349-4bf3-8267-b12b5adf809d', '/opt/spark/python', '/home/iceberg', '/usr/local/lib/python39.zip', '/usr/local/lib/python3.9', '/usr/local/lib/python3.9/lib-dynload', '', '/usr/local/lib/python3.9/site-packages', '../src', '../src']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 sys.path.append("../src")  # tell Python where to find modules
#       4 print(sys.path)
# ----> 5 from app_config import AppConfig
#       7 config = AppConfig("../mne_configs/OCR_INPUT.json")
#
# ModuleNotFoundError: No module named 'app_config'

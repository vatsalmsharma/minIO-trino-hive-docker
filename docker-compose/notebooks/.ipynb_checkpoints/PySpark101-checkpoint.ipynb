# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import expr, col
spark = SparkSession.builder.appName("Jupyter").getOrCreate()

spark
# Out:
# 25/09/09 12:31:46 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://79cd2110689c:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS poc
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS iceberg.ip.nyc_taxi_zone_ice (
#     location_id VARCHAR(20),
#     borough VARCHAR(50),
#     zone VARCHAR(20),
#     service_zone VARCHAR(50)
# )
# USING iceberg;
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# DESCRIBE EXTENDED iceberg.ip.nyc_taxi_zone_ice;
# Out:
# +------------------------------+---------------------------------------------------------------------------------------------------------+---------+
# |                     col_name |                                                                                               data_type | comment |
# +------------------------------+---------------------------------------------------------------------------------------------------------+---------+
# |                  location_id |                                                                                                  string |    None |
# |                      borough |                                                                                                  string |    None |
# |                         zone |                                                                                                  string |    None |
# ...

# %%
# %%sql
# select * from hive.hp.nyc_taxi_zone_hive;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select * from hive.hp.nyc_taxi_zone_hive;\n')
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.ipython/profile_default/startup/00-prettytables.py:81, in sql(line, cell)
#      79         return _to_table(df, num_rows=args.limit)
#      80 else:
# ...

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS poc.events (
#     url STRING,
#     referrer STRING,
#     browser_family STRING,
#     os_family STRING,
#     device_family STRING,
#     host STRING,
#     event_time TIMESTAMP,
#     event_date DATE
# )
# USING iceberg;
# Out:
# ++
# ||
# ++
# ++

# %%
# Create DataFrame
data = [(1, "James", 30, "M"), (2, "Ann", 40, "F")]
columns = ["id", "name", "age", "gender"]
sampleDF = spark.sparkContext.parallelize(data).toDF(columns)

# %%
# Create a Hive Internal table
sampleDF.write.mode("overwrite").saveAsTable("emp.employee")

# %%
# %%sql
#
# select * from emp.employee;
# Out:
# +----+-------+-----+--------+
# | id |  name | age | gender |
# +----+-------+-----+--------+
# |  1 | James |  30 |      M |
# |  2 |   Ann |  40 |      F |
# +----+-------+-----+--------+

# %%
# %%sql
# DESCRIBE EXTENDED emp.employee;
# Out:
# +------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |                     col_name |                                                                                                                                                                                    data_type | comment |
# +------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |                           id |                                                                                                                                                                                       bigint |    None |
# ...

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS nyc
# Out:
# ++
# ||
# ++
# ++

# %%
df = spark.read.parquet("/home/iceberg/data/yellow_tripdata_2025-01.parquet")
df.write.saveAsTable("nyc.taxis")

# %%
# %%sql
#
# DESCRIBE EXTENDED nyc.taxis
# Out:
# +------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |                     col_name |                                                                                                                                                                                     data_type | comment |
# +------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |                     VendorID |                                                                                                                                                                                           int |    None |
# ...

# %%
# %%sql
#
# SELECT COUNT(*) as cnt
# FROM nyc.taxis
# Out:
# +---------+
# |     cnt |
# +---------+
# | 3475226 |
# +---------+

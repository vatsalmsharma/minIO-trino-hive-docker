# %%
base_path = "/home/iceberg/"
ocr_input_file = "mne_configs/OCR_INPUT.json"

# %%
ocr_in_path = base_path + ocr_input_file
ocr_in_path
# Out:
# '/home/iceberg/mne_configs/OCR_INPUT.json'

# %%
import json

# %%
with open(ocr_in_path, 'r') as file:
    data = json.load(file)
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with open(ocr_in_path, 'r') as file:
#       2     data = json.load(file)
#       3 print(data)
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/iceberg/mne_configs/OCR_INPUT.json'

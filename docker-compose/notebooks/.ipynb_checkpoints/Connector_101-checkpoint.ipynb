# %%
# import sys
# sys.path.append("/home/iceberg/libs")

# %%
from pyspark.sql import SparkSession
from libs.postgres_connector import PostgresConnector

# %%
spark = SparkSession.builder \
    .appName("Demo") \
    .getOrCreate()
# Out:
# 25/09/20 18:50:40 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# Init connectors
pg = PostgresConnector(spark, db="spark_demo", user="admin", password="admin")

# %%
df_pg = pg.read_table("customers")
df_pg.show()
# Out:
# +---+----+-----+---+
# | id|name|email|age|
# +---+----+-----+---+
# +---+----+-----+---+

# %%
from libs.csv_connector import CsvConnector
from libs.parquet_connector import ParquetConnector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from libs.csv_connector import CsvConnector
#       2 from libs.parquet_connector import ParquetConnector
#
# ModuleNotFoundError: No module named 'libs.csv_connector'

# %%
df_csv = csv.read_csv("/data/taxi_zone_lookup.csv")
df_csv.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_csv = csv.read_csv("/data/taxi_zone_lookup.csv")
#       2 df_csv.show()
#
# NameError: name 'csv' is not defined

# %%
df_pq = pq.read_parquet("/data/customers_parquet")
df_pq.show()
